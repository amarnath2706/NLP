# %%
import nltk
#By default this package is not available in python so we need to install it manually
from gensim.models import Word2Vec
from nltk.corpus import stopwords
import re
# Out:
# D:\Anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
#!pip install gensim
# Out:
# Collecting gensim
#   Downloading https://files.pythonhosted.org/packages/15/89/b785d557e3c806abc8beaae664571d71e8c4eb736a2c32b69aba9932cbd1/gensim-4.0.1-cp37-cp37m-win_amd64.whl (23.9MB)
# Requirement already satisfied: scipy>=0.18.1 in d:\anaconda3\lib\site-packages (from gensim) (1.4.1)
# Collecting Cython==0.29.21 (from gensim)
#   Downloading https://files.pythonhosted.org/packages/79/f4/28002920834b292a4dece255d59860c9996d16002f1bca30d7794e0b7884/Cython-0.29.21-cp37-cp37m-win_amd64.whl (1.6MB)
# Requirement already satisfied: numpy>=1.11.3 in d:\anaconda3\lib\site-packages (from gensim) (1.20.3)
# Requirement already satisfied: smart-open>=1.8.1 in d:\anaconda3\lib\site-packages (from gensim) (3.0.0)
# Requirement already satisfied: requests in d:\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (2.22.0)
# Requirement already satisfied: idna<2.9,>=2.5 in d:\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in d:\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2019.9.11)
# Installing collected packages: Cython, gensim
#   Found existing installation: Cython 0.29.13
#     Uninstalling Cython-0.29.13:
#       Successfully uninstalled Cython-0.29.13
# Successfully installed Cython-0.29.21 gensim-4.0.1

# %%
paragraph= """ An airline is a company that provides air transport services for traveling passengers and freight. 
Airlines utilize aircraft to supply these services and may form partnerships or alliances with other airlines for codeshare agreements, in which they both offer and operate the same flight. 
Generally, airline companies are recognized with an air operating certificate or license issued by a governmental aviation body. 
Airlines may be scheduled or charter operators.
Airline ownership has seen a shift from mostly personal ownership until the 1930s to government-ownership of major airlines from the 1940s to 1980s and back to large-scale privatization following the mid-1980s.
Since the 1980s, there has also been a trend of major airline mergers and the formation of airline alliances.
The largest alliances are Star Alliance, SkyTeam and Oneworld, and these three collectively accounted for more than 60% of global commercial air traffic in 2015.
Airline alliances coordinate their passenger service programs (such as lounges and frequent-flyer programs), offer special interline tickets and often engage in extensive codesharing (sometimes systemwide).
As of 2019, the largest airline by passengers carried and fleet size was the American Airlines Group, while Delta Air Lines was the largest by revenue.
Lufthansa Group was the largest by number of employees, FedEx Express by freight tonne-kilometres, Turkish Airlines by number of countries served and UPS Airlines by number of destinations served[9] (though United Airlines was the largest passenger airline by number of destinations served).
"""
paragraph
# Out:
# ' An airline is a company that provides air transport services for traveling passengers and freight. \nAirlines utilize aircraft to supply these services and may form partnerships or alliances with other airlines for codeshare agreements, in which they both offer and operate the same flight. \nGenerally, airline companies are recognized with an air operating certificate or license issued by a governmental aviation body. \nAirlines may be scheduled or charter operators.\nAirline ownership has seen a shift from mostly personal ownership until the 1930s to government-ownership of major airlines from the 1940s to 1980s and back to large-scale privatization following the mid-1980s.\nSince the 1980s, there has also been a trend of major airline mergers and the formation of airline alliances.\nThe largest alliances are Star Alliance, SkyTeam and Oneworld, and these three collectively accounted for more than 60% of global commercial air traffic in 2015.\nAirline alliances coordinate their passenger service programs (such as lounges and frequent-flyer programs), offer special interline tickets and often engage in extensive codesharing (sometimes systemwide).\nAs of 2019, the largest airline by passengers carried and fleet size was the American Airlines Group, while Delta Air Lines was the largest by revenue.\nLufthansa Group was the largest by number of employees, FedEx Express by freight tonne-kilometres, Turkish Airlines by number of countries served and UPS Airlines by number of destinations served[9] (though United Airlines was the largest passenger airline by number of destinations served).\n'

# %%
# Preprocessing the data
text = re.sub(r'\[[0-9]*\]',' ',paragraph)
text = re.sub(r'\s+',' ',text)
text = text.lower()
text = re.sub(r'\d',' ',text)
text = re.sub(r'\s+',' ',text)

# %%
text
# Out:
# ' an airline is a company that provides air transport services for traveling passengers and freight. airlines utilize aircraft to supply these services and may form partnerships or alliances with other airlines for codeshare agreements, in which they both offer and operate the same flight. generally, airline companies are recognized with an air operating certificate or license issued by a governmental aviation body. airlines may be scheduled or charter operators. airline ownership has seen a shift from mostly personal ownership until the s to government-ownership of major airlines from the s to s and back to large-scale privatization following the mid- s. since the s, there has also been a trend of major airline mergers and the formation of airline alliances. the largest alliances are star alliance, skyteam and oneworld, and these three collectively accounted for more than % of global commercial air traffic in . airline alliances coordinate their passenger service programs (such as lounges and frequent-flyer programs), offer special interline tickets and often engage in extensive codesharing (sometimes systemwide). as of , the largest airline by passengers carried and fleet size was the american airlines group, while delta air lines was the largest by revenue. lufthansa group was the largest by number of employees, fedex express by freight tonne-kilometres, turkish airlines by number of countries served and ups airlines by number of destinations served (though united airlines was the largest passenger airline by number of destinations served). '

# %%
#Convert text into a sentences
sentences = nltk.sent_tokenize(text)
sentences
# Out:
# [' an airline is a company that provides air transport services for traveling passengers and freight.',
#  'airlines utilize aircraft to supply these services and may form partnerships or alliances with other airlines for codeshare agreements, in which they both offer and operate the same flight.',
#  'generally, airline companies are recognized with an air operating certificate or license issued by a governmental aviation body.',
#  'airlines may be scheduled or charter operators.',
#  'airline ownership has seen a shift from mostly personal ownership until the s to government-ownership of major airlines from the s to s and back to large-scale privatization following the mid- s. since the s, there has also been a trend of major airline mergers and the formation of airline alliances.',
#  'the largest alliances are star alliance, skyteam and oneworld, and these three collectively accounted for more than % of global commercial air traffic in .',
#  'airline alliances coordinate their passenger service programs (such as lounges and frequent-flyer programs), offer special interline tickets and often engage in extensive codesharing (sometimes systemwide).',
#  'as of , the largest airline by passengers carried and fleet size was the american airlines group, while delta air lines was the largest by revenue.',
#  'lufthansa group was the largest by number of employees, fedex express by freight tonne-kilometres, turkish airlines by number of countries served and ups airlines by number of destinations served (though united airlines was the largest passenger airline by number of destinations served).']

# %%
#Convert sentences into words
sentences = [nltk.word_tokenize(sentence) for sentence in sentences]
sentences
# Out:
# [['an',
#   'airline',
#   'is',
#   'a',
#   'company',
#   'that',
#   'provides',
#   'air',
#   'transport',
#   'services',
#   'for',
#   'traveling',
#   'passengers',
#   'and',
#   'freight',
#   '.'],
#  ['airlines',
#   'utilize',
#   'aircraft',
#   'to',
#   'supply',
#   'these',
#   'services',
#   'and',
#   'may',
#   'form',
#   'partnerships',
#   'or',
#   'alliances',
#   'with',
#   'other',
#   'airlines',
#   'for',
#   'codeshare',
#   'agreements',
#   ',',
#   'in',
#   'which',
#   'they',
#   'both',
#   'offer',
#   'and',
#   'operate',
#   'the',
#   'same',
#   'flight',
#   '.'],
#  ['generally',
#   ',',
#   'airline',
#   'companies',
#   'are',
#   'recognized',
#   'with',
#   'an',
#   'air',
#   'operating',
#   'certificate',
#   'or',
#   'license',
#   'issued',
#   'by',
#   'a',
#   'governmental',
#   'aviation',
#   'body',
#   '.'],
#  ['airlines', 'may', 'be', 'scheduled', 'or', 'charter', 'operators', '.'],
#  ['airline',
#   'ownership',
#   'has',
#   'seen',
#   'a',
#   'shift',
#   'from',
#   'mostly',
#   'personal',
#   'ownership',
#   'until',
#   'the',
#   's',
#   'to',
#   'government-ownership',
#   'of',
#   'major',
#   'airlines',
#   'from',
#   'the',
#   's',
#   'to',
#   's',
#   'and',
#   'back',
#   'to',
#   'large-scale',
#   'privatization',
#   'following',
#   'the',
#   'mid-',
#   's.',
#   'since',
#   'the',
#   's',
#   ',',
#   'there',
#   'has',
#   'also',
#   'been',
#   'a',
#   'trend',
#   'of',
#   'major',
#   'airline',
#   'mergers',
#   'and',
#   'the',
#   'formation',
#   'of',
#   'airline',
#   'alliances',
#   '.'],
#  ['the',
#   'largest',
#   'alliances',
#   'are',
#   'star',
#   'alliance',
#   ',',
#   'skyteam',
#   'and',
#   'oneworld',
#   ',',
#   'and',
#   'these',
#   'three',
#   'collectively',
#   'accounted',
#   'for',
#   'more',
#   'than',
#   '%',
#   'of',
#   'global',
#   'commercial',
#   'air',
#   'traffic',
#   'in',
#   '.'],
#  ['airline',
#   'alliances',
#   'coordinate',
#   'their',
#   'passenger',
#   'service',
#   'programs',
#   '(',
#   'such',
#   'as',
#   'lounges',
#   'and',
#   'frequent-flyer',
#   'programs',
#   ')',
#   ',',
#   'offer',
#   'special',
#   'interline',
#   'tickets',
#   'and',
#   'often',
#   'engage',
#   'in',
#   'extensive',
#   'codesharing',
#   '(',
#   'sometimes',
#   'systemwide',
#   ')',
#   '.'],
#  ['as',
#   'of',
#   ',',
#   'the',
#   'largest',
#   'airline',
#   'by',
#   'passengers',
#   'carried',
#   'and',
#   'fleet',
#   'size',
#   'was',
#   'the',
#   'american',
#   'airlines',
#   'group',
#   ',',
#   'while',
#   'delta',
#   'air',
#   'lines',
#   'was',
#   'the',
#   'largest',
#   'by',
#   'revenue',
#   '.'],
#  ['lufthansa',
#   'group',
#   'was',
#   'the',
#   'largest',
#   'by',
#   'number',
#   'of',
#   'employees',
#   ',',
#   'fedex',
#   'express',
#   'by',
#   'freight',
#   'tonne-kilometres',
#   ',',
#   'turkish',
#   'airlines',
#   'by',
#   'number',
#   'of',
#   'countries',
#   'served',
#   'and',
#   'ups',
#   'airlines',
#   'by',
#   'number',
#   'of',
#   'destinations',
#   'served',
#   '(',
#   'though',
#   'united',
#   'airlines',
#   'was',
#   'the',
#   'largest',
#   'passenger',
#   'airline',
#   'by',
#   'number',
#   'of',
#   'destinations',
#   'served',
#   ')',
#   '.']]

# %%
#remove stopwords
for i in range(len(sentences)):
    sentences[i] = [word for word in sentences[i] if word not in stopwords.words('english')]
sentences
# Out:
# [['airline',
#   'company',
#   'provides',
#   'air',
#   'transport',
#   'services',
#   'traveling',
#   'passengers',
#   'freight',
#   '.'],
#  ['airlines',
#   'utilize',
#   'aircraft',
#   'supply',
#   'services',
#   'may',
#   'form',
#   'partnerships',
#   'alliances',
#   'airlines',
#   'codeshare',
#   'agreements',
#   ',',
#   'offer',
#   'operate',
#   'flight',
#   '.'],
#  ['generally',
#   ',',
#   'airline',
#   'companies',
#   'recognized',
#   'air',
#   'operating',
#   'certificate',
#   'license',
#   'issued',
#   'governmental',
#   'aviation',
#   'body',
#   '.'],
#  ['airlines', 'may', 'scheduled', 'charter', 'operators', '.'],
#  ['airline',
#   'ownership',
#   'seen',
#   'shift',
#   'mostly',
#   'personal',
#   'ownership',
#   'government-ownership',
#   'major',
#   'airlines',
#   'back',
#   'large-scale',
#   'privatization',
#   'following',
#   'mid-',
#   's.',
#   'since',
#   ',',
#   'also',
#   'trend',
#   'major',
#   'airline',
#   'mergers',
#   'formation',
#   'airline',
#   'alliances',
#   '.'],
#  ['largest',
#   'alliances',
#   'star',
#   'alliance',
#   ',',
#   'skyteam',
#   'oneworld',
#   ',',
#   'three',
#   'collectively',
#   'accounted',
#   '%',
#   'global',
#   'commercial',
#   'air',
#   'traffic',
#   '.'],
#  ['airline',
#   'alliances',
#   'coordinate',
#   'passenger',
#   'service',
#   'programs',
#   '(',
#   'lounges',
#   'frequent-flyer',
#   'programs',
#   ')',
#   ',',
#   'offer',
#   'special',
#   'interline',
#   'tickets',
#   'often',
#   'engage',
#   'extensive',
#   'codesharing',
#   '(',
#   'sometimes',
#   'systemwide',
#   ')',
#   '.'],
#  [',',
#   'largest',
#   'airline',
#   'passengers',
#   'carried',
#   'fleet',
#   'size',
#   'american',
#   'airlines',
#   'group',
#   ',',
#   'delta',
#   'air',
#   'lines',
#   'largest',
#   'revenue',
#   '.'],
#  ['lufthansa',
#   'group',
#   'largest',
#   'number',
#   'employees',
#   ',',
#   'fedex',
#   'express',
#   'freight',
#   'tonne-kilometres',
#   ',',
#   'turkish',
#   'airlines',
#   'number',
#   'countries',
#   'served',
#   'ups',
#   'airlines',
#   'number',
#   'destinations',
#   'served',
#   '(',
#   'though',
#   'united',
#   'airlines',
#   'largest',
#   'passenger',
#   'airline',
#   'number',
#   'destinations',
#   'served',
#   ')',
#   '.']]

# %%
# Training the Word2Vec model
#count = 1 - if the the word is present atleast one time then i do some preprocess on top of the word
model = Word2Vec(sentences, min_count=1)
print(model)
# Out:
# Word2Vec(vocab=105, vector_size=100, alpha=0.025)

# %%
#Finding the specific vectors adn thier relationship 
vector = model.wv['air']
vector
# Out:
# array([ 8.1675425e-03, -4.4564228e-03, -1.0657376e-03,  9.8665548e-04,
#        -1.8667297e-04,  1.0834265e-03,  6.1333580e-03,  2.5647707e-05,
#        -3.2559752e-03, -1.5462500e-03,  5.8930782e-03,  1.4929980e-03,
#        -7.1791763e-04,  9.3383500e-03, -4.9084607e-03, -8.5600332e-04,
#         9.1754561e-03,  6.7250379e-03,  1.4766797e-03, -8.9207310e-03,
#         1.1580586e-03, -2.3039659e-03,  9.3756076e-03,  1.1727745e-03,
#         1.4697524e-03,  2.4087355e-03, -1.8642540e-03, -5.0071087e-03,
#         2.3737273e-04, -2.0107478e-03,  6.6194334e-03,  8.9280959e-03,
#        -6.5159623e-04,  2.9471044e-03, -6.1109043e-03,  1.7248027e-03,
#        -6.9283405e-03, -8.7221423e-03, -5.9034773e-03, -8.9977626e-03,
#         7.2872951e-03, -5.8084689e-03,  8.2936902e-03, -7.2482526e-03,
#         3.4697845e-03,  9.6654454e-03, -7.8285383e-03, -9.9541880e-03,
#        -4.2990604e-03, -2.6672785e-03, -2.7224389e-04, -8.8476306e-03,
#        -8.6045153e-03,  2.8051636e-03, -8.2186870e-03, -9.0375701e-03,
#        -2.3306180e-03, -8.6322138e-03, -7.0647043e-03, -8.3800564e-03,
#        -2.7884694e-04, -4.5844098e-03,  6.6407709e-03,  1.5454052e-03,
#        -3.3291311e-03,  6.1631924e-03, -6.0061621e-03, -4.6360027e-03,
#        -7.2360472e-03, -4.3110303e-03, -1.8365653e-03,  6.5045683e-03,
#        -2.7590108e-03,  4.9160337e-03,  6.9412328e-03, -7.4506314e-03,
#         4.5755790e-03,  6.1320406e-03, -2.9526786e-03,  6.6035935e-03,
#         6.1172098e-03, -6.4269439e-03, -6.8186345e-03,  2.5851752e-03,
#        -1.6330488e-03, -6.0797427e-03,  9.5356563e-03, -5.1200786e-03,
#        -6.5322593e-03, -8.0625105e-05, -2.6661002e-03,  4.4875537e-04,
#        -3.5574127e-03, -4.3391518e-04, -6.7057193e-04,  8.2024536e-04,
#         8.1873154e-03, -5.7692872e-03, -1.6594416e-03,  5.5348831e-03],
#       dtype=float32)

# %%
#Finding the most similar words
similar = model.wv.most_similar('air')
similar
# Out:
# [('flight', 0.3504221439361572),
#  ('charter', 0.3039131760597229),
#  ('partnerships', 0.24927611649036407),
#  ('employees', 0.22354884445667267),
#  ('body', 0.17821979522705078),
#  ('programs', 0.16500768065452576),
#  ('%', 0.16432508826255798),
#  ('issued', 0.16372530162334442),
#  ('transport', 0.15614405274391174),
#  ('codesharing', 0.1534377783536911)]
